# %%
import numpy as np  
y_val = np.load('/home/nano_photonics/linking variational autoencoder complete data/linking_variational_autoencoder/y_val.npy')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.colors import ListedColormap

# Load saved UMAP embeddings
umap_shape_embeds = np.load('/home/nano_photonics/linking variational autoencoder complete data/linking_variational_autoencoder/umap_shape_embeds_8.npy')
umap_spectrum_embeds = np.load('/home/nano_photonics/linking variational autoencoder complete data/linking_variational_autoencoder/umap_spectrum_embeds_8.npy')
# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
# Create a custom colormap
custom_cmap = ListedColormap(my_colors)

# Plot UMAP embeddings in a row
plt.figure(figsize=(15, 8))
# Define a 1x2 grid (removed extra subplots for color bar)
gs = GridSpec(1, 2, width_ratios=[1, 1])  


# Plot Shape Latent Space
ax0 = plt.subplot(gs[0])
scatter_shape = ax0.scatter(umap_shape_embeds[:, 0], umap_shape_embeds[:, 1], c=y_val, cmap=custom_cmap, s=50)  # Adjusted marker size
# ax0.set_title('Shape', fontsize=18, fontweight='bold')
ax0.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
# plt.xlim(x_min, x_max)
# plt.ylim(y_min, y_max)
legend0 = ax0.legend(title='Shape', fontsize=18)  # Adjusted legend size
legend0.get_title().set_fontweight('bold')  # Set fontweight for legend title
legend0.get_title().set_fontsize(22)  # Adjusted font size for legend text
legend0.get_title().set_fontfamily('serif')  # Set font family for legend title

# Plot Spectrum Latent Space
ax1 = plt.subplot(gs[1])
scatter_spectrum = ax1.scatter(umap_spectrum_embeds[:, 0], umap_spectrum_embeds[:, 1], c=y_val, cmap=custom_cmap, s=50)  # Adjusted marker size
# ax1.set_title('Spectrum', fontsize=18, fontweight='bold')
ax1.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
# plt.xlim(x_min, x_max)
# plt.ylim(y_min, y_max)
legend1 = ax1.legend(title='Spectrum', fontsize=18)  # Adjusted legend size
legend1.get_title().set_fontweight('bold')  # Set fontweight for legend title-
legend1.get_title().set_fontsize(22)  # Adjusted font size for legend text
legend1.get_title().set_fontfamily('serif')  # Set font family for legend title

# Save the figure with DPI value
plt.tight_layout()
# Change the file format if needed (e.g., "combined_image.pdf")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 0 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 1 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 2 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 3 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 4 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 5 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 6 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 7 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 8 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 9 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 10 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 11 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 12 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 13 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 14 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 15 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 16 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 17 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 18 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 19 # Replace with the desired class label
plot_class_clusters(class_label)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Load UMAP embeddings for shape and spectrum latent spaces (replace with your actual data loading)
umap_shape_embeds = np.load('umap_shape_embeds.npy')
umap_spectrum_embeds = np.load('umap_spectrum_embeds.npy')

# Define your custom list of colors (replace with your chosen colors)
my_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#000000', '#E5E4E2', '#f032e6', '#bfef45', '#0000FF', '#E9967A', '#9400D3', '#FFD700', '#FF5C5C', '#6082B6', '#556B2F']
custom_cmap = ListedColormap(my_colors)

# Example function to plot shape and spectrum clusters for a specific class
def plot_class_clusters(class_label):
    # Convert y_val to integers (replace with your actual labels)
    y_val_int = y_val.astype(int)

    # Plot shape latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_shape_embeds[y_val_int == class_label, 0], umap_shape_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Shape Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

    # Plot spectrum latent space for the specified class
    plt.figure(figsize=(8, 8))
    plt.scatter(umap_spectrum_embeds[y_val_int == class_label, 0], umap_spectrum_embeds[y_val_int == class_label, 1], c=my_colors[class_label], label=f'Label {class_label}')
    plt.title(f'Spectrum Latent Space for Label {class_label}')
    plt.xlabel('UMAP Dimension 1')
    plt.ylabel('UMAP Dimension 2')
    plt.xlim(-10, 25)
    plt.ylim(-15, 25)
    plt.legend()
    plt.show()

# Example usage:
# Replace `class_label` with the actual class label you want to plot
class_label = 20 # Replace with the desired class label
plot_class_clusters(class_label)
